# %%
#
# hw9pr2b.py - the k-means algorithm and posterizing ~ cs181/cs35 spring 2021
#

# %%
# import everything we need...
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import utils
import cv2
import seaborn as sns
sns.set(style="darkgrid")

# %%
IMAGE_NAME = "./thematrix.png"

image = cv2.imread(IMAGE_NAME, cv2.IMREAD_COLOR)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

image_pixels = image.reshape((image.shape[0] * image.shape[1], 3))

print(image_pixels)
# Out:
# [[ 54 122  76]
#  [ 68 135  87]
#  [ 79 144  94]
#  ...
#  [  5  33  16]
#  [  6  38  19]
#  [  1  35  15]]

# %%
NUM_MEANS = 3
clusters = KMeans(n_clusters = NUM_MEANS)
clusters.fit(image_pixels)

count = 0
for center in clusters.cluster_centers_:
    print("Center #", count, " == ", center)
    # note that the center's values are floats, not ints!
    center_integers = [int(p) for p in center]
    print("   and as ints:", center_integers)
    count += 1
    
hist = utils.centroid_histogram(clusters)
bar = utils.plot_colors(hist, clusters.cluster_centers_)

plt.figure()
plt.axis("off")
plt.imshow(image)

fig, ax = plt.subplots(1,1, sharex=False, sharey=False)
title = str(NUM_MEANS)+" means"
ax.imshow(bar); ax.set_title(title); ax.axis('off')
# Out:
# Center # 0  ==  [156.83235614 209.72235949 160.07850322]
#    and as ints: [156, 209, 160]
# Center # 1  ==  [ 6.21852335 20.83810374 12.83747455]
#    and as ints: [6, 20, 12]
# Center # 2  ==  [ 76.60953719 143.38085169  98.11988762]
#    and as ints: [76, 143, 98]
# (-0.5, 299.5, 49.5, -0.5)

# %%
NUM_MEANS = 5
clusters = KMeans(n_clusters = NUM_MEANS)
clusters.fit(image_pixels)

count = 0
for center in clusters.cluster_centers_:
    print("Center #", count, " == ", center)
    # note that the center's values are floats, not ints!
    center_integers = [int(p) for p in center]
    print("   and as ints:", center_integers)
    count += 1
    
hist = utils.centroid_histogram(clusters)
bar = utils.plot_colors(hist, clusters.cluster_centers_)

plt.figure()
plt.axis("off")
plt.imshow(image)

fig, ax = plt.subplots(1,1)
title = str(NUM_MEANS)+" means"
ax.imshow(bar); ax.set_title(title); ax.axis('off')
# Out:
# Center # 0  ==  [136.21882377 195.38637997 143.27963666]
#    and as ints: [136, 195, 143]
# Center # 1  ==  [2.2932186  9.39371236 6.21228986]
#    and as ints: [2, 9, 6]
# Center # 2  ==  [31.33165698 82.92198419 50.99722422]
#    and as ints: [31, 82, 50]
# Center # 3  ==  [ 82.17565821 150.74610321 104.07676466]
#    and as ints: [82, 150, 104]
# Center # 4  ==  [199.61231991 239.31542193 196.0575566 ]
#    and as ints: [199, 239, 196]
# (-0.5, 299.5, 49.5, -0.5)

# %%
NUM_MEANS = 7
clusters = KMeans(n_clusters = NUM_MEANS)
clusters.fit(image_pixels)

count = 0
for center in clusters.cluster_centers_:
    print("Center #", count, " == ", center)
    # note that the center's values are floats, not ints!
    center_integers = [int(p) for p in center]
    print("   and as ints:", center_integers)
    count += 1
    
hist = utils.centroid_histogram(clusters)
bar = utils.plot_colors(hist, clusters.cluster_centers_)

plt.figure()
plt.axis("off")
plt.imshow(image)

fig, ax = plt.subplots(1,1)
title = str(NUM_MEANS)+" means"
ax.imshow(bar); ax.set_title(title); ax.axis('off')
# Out:
# Center # 0  ==  [14.93955006 52.47329555 30.3535978 ]
#    and as ints: [14, 52, 30]
# Center # 1  ==  [108.9154161  175.33722517 124.49988896]
#    and as ints: [108, 175, 124]
# Center # 2  ==  [ 42.00627812 100.69587737  63.8395417 ]
#    and as ints: [42, 100, 63]
# Center # 3  ==  [212.4464845  246.09936278 206.27659574]
#    and as ints: [212, 246, 206]
# Center # 4  ==  [ 75.3700565  144.0581607   98.57799749]
#    and as ints: [75, 144, 98]
# Center # 5  ==  [1.19879227 4.50002495 3.56999318]
#    and as ints: [1, 4, 3]
# Center # 6  ==  [151.58249828 206.98513186 155.05487827]
#    and as ints: [151, 206, 155]
# (-0.5, 299.5, 49.5, -0.5)

# %%
NUM_MEANS = 3
clusters = KMeans(n_clusters = NUM_MEANS)
clusters.fit(image_pixels)

NUM_MEANS_1 = 5
clusters_1 = KMeans(n_clusters = NUM_MEANS_1)
clusters_1.fit(image_pixels)

NUM_MEANS_2 = 7
clusters_2 = KMeans(n_clusters = NUM_MEANS_2)
clusters_2.fit(image_pixels)

NUM_MEANS_3 = 9
clusters_3 = KMeans(n_clusters = NUM_MEANS_3)
clusters_3.fit(image_pixels)
    
hist = utils.centroid_histogram(clusters)
bar = utils.plot_colors(hist, clusters.cluster_centers_)


hist_1 = utils.centroid_histogram(clusters_1)
bar_1 = utils.plot_colors(hist, clusters_1.cluster_centers_)


hist_2 = utils.centroid_histogram(clusters_2)
bar_2 = utils.plot_colors(hist, clusters_2.cluster_centers_)

hist_3 = utils.centroid_histogram(clusters_3)
bar_3 = utils.plot_colors(hist, clusters_3.cluster_centers_)

plt.figure()
plt.axis("off")
plt.imshow(image)


fig, ax = plt.subplots(nrows=2, ncols=2, sharex=False, sharey=False)
title = str(NUM_MEANS)+" means"
title_1 = str(NUM_MEANS_1)+" means"
title_2 = str(NUM_MEANS_2)+" means"
title_3 = str(NUM_MEANS_3)+" means"
ax[0,0].imshow(bar);    ax[0,0].set_title(title)
ax[0,1].imshow(bar_1);    ax[0,1].set_title(title_1)
ax[1,0].imshow(bar_2);    ax[1,0].set_title(title_2)
ax[1,1].imshow(bar_3);    ax[1,1].set_title(title_3)
for row in range(2):
    for col in range(2):
        ax[row,col].axis('off')
plt.show(block=fig)

# %%
# Reshaping the image into a 2D array of pixels and 3 color values (RGB)
pixel_vals = image.reshape((-1,3))
  
# Convert to float type
pixel_vals = np.float32(pixel_vals)

# %%
#the below line of code defines the criteria for the algorithm to stop running, 
#which will happen is 100 iterations are run or the epsilon (which is the required accuracy) 
#becomes 85%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.85)
  
# then perform k-means clustering wit h number of clusters defined as 3
#also random centres are initally chosed for k-means clustering
k = 3
retval, labels, centers = cv2.kmeans(pixel_vals, k, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)
  
# convert data into 8-bit values
centers = np.uint8(centers)
segmented_data = centers[labels.flatten()]
  
# reshape data into the original image dimensions
segmented_image = segmented_data.reshape((image.shape))
  
plt.imshow(segmented_image); plt.axis("off")
# Out:
# (-0.5, 599.5, 337.5, -0.5)

# %%
#the below line of code defines the criteria for the algorithm to stop running, 
#which will happen is 100 iterations are run or the epsilon (which is the required accuracy) 
#becomes 85%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.85)
  
# then perform k-means clustering wit h number of clusters defined as 7
#also random centres are initally chosed for k-means clustering
k = 7
retval, labels, centers = cv2.kmeans(pixel_vals, k, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)
  
# convert data into 8-bit values
centers = np.uint8(centers)
segmented_data = centers[labels.flatten()]
  
# reshape data into the original image dimensions
segmented_image = segmented_data.reshape((image.shape))
  
plt.imshow(segmented_image); plt.axis("off")
# Out:
# (-0.5, 599.5, 337.5, -0.5)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import utils
import cv2
import seaborn as sns
sns.set(style="darkgrid")

# %%
IMAGE_NAME = "./princess_self.png"

image = cv2.imread(IMAGE_NAME, cv2.IMREAD_COLOR)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

image_pixels = image.reshape((image.shape[0] * image.shape[1], 3))

# %%
NUM_MEANS = 5
clusters = KMeans(n_clusters = NUM_MEANS)
clusters.fit(image_pixels)

hist = utils.centroid_histogram(clusters)
bar = utils.plot_colors(hist, clusters.cluster_centers_)

# %%
plt.figure()
plt.axis("off")
plt.imshow(image)

fig, ax = plt.subplots(1,1, sharex=False, sharey=False)
title = str(NUM_MEANS)+" means"
ax.imshow(bar); ax.set_title(title); ax.axis('off')
# Out:
# (-0.5, 299.5, 49.5, -0.5)

# %%
pixel_vals = image.reshape((-1,3))
  
# Convert to float type
pixel_vals = np.float32(pixel_vals)

# %%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.85)

k = 10
retval, labels, centers = cv2.kmeans(pixel_vals, k, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)

centers = np.uint8(centers)
segmented_data = centers[labels.flatten()]
  
# reshape data into the original image dimensions
segmented_image = segmented_data.reshape((image.shape))
  
plt.imshow(segmented_image); plt.axis("off")
# Out:
# (-0.5, 1138.5, 631.5, -0.5)

# %%
from sklearn.cluster import MiniBatchKMeans, KMeans
import numpy as np
import argparse
from cv2 import cv2

# %%
pixel_vals = np.float32(pixel_vals)

# %%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.85)
retval, labels, centers = cv2.kmeans(pixel_vals, k, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)

# %%
print(retval, labels, centers)
# Out:
# 468423274.52045274 [[2]
#  [2]
#  [2]
#  ...
#  [2]
#  [2]
#  [2]] [[184.20631   91.59882   75.09462 ]
#  [208.68547  128.31718  112.587654]
#  [170.85631  155.12674  164.87682 ]
#  [103.784134  37.855495  31.654655]
#  [137.59155   69.54412   59.36719 ]
#  [ 40.59145   24.57251   22.629879]
#  [149.43462  102.87244  102.51542 ]
#  [216.90697  206.56914  212.67514 ]
#  [230.43553  172.16272  150.1989  ]
#  [ 69.44202   56.181248  57.92406 ]]

# %%
center = np.uint8(centers)
print(center)
# Out:
# [[184  91  75]
#  [208 128 112]
#  [170 155 164]
#  [103  37  31]
#  [137  69  59]
#  [ 40  24  22]
#  [149 102 102]
#  [216 206 212]
#  [230 172 150]
#  [ 69  56  57]]

# %%
segmented_data = center[labels.flatten()] 
print(segmented_data)
# Out:
# [[170 155 164]
#  [170 155 164]
#  [170 155 164]
#  ...
#  [170 155 164]
#  [170 155 164]
#  [170 155 164]]

# %%
segmented_image = segmented_data.reshape((image.shape))

# %%
plt.figure()
plt.axis("off")
plt.imshow(segmented_image)

# %%
image_bgr = cv2.cvtColor(segmented_image, cv2.COLOR_RGB2BGR) 
cv2.imwrite('new_image.png',image_bgr)
# Out:
# True
